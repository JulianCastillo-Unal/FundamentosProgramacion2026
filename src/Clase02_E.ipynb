# %% [markdown]
# <div align="center">
# <p><img alt="Unal" height="150px" src="https://minas.medellin.unal.edu.co/proyectos/one-health-consortium/images/unal.png" align="center" hspace="10px" vspace="0px"></p>
# </div>
# <div> </div>
#
#
# <p>
# <h6 align="center"> <b> </b> </h6>
# <h1 align="center"> <b> Fundamentos de Programación </b> </h1>
# <hr size=10 noshade color="gray">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <br></br><br></br>
# </p>
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> <strong>Docente: Julián Castillo </strong></h1>
# <h2><a href="mailto:jacastil@unal.edu.co">✉ Julián Castillo</a></h2>
# <h3>Profesor Asistente - Departamento de Ciencias de la Computación y de la Decisión</h3>
# <h3>Teoría Grupos 19, 20 y 21 (Jueves 14-16 -> 12-201)</h3>
# <h3>Practicas Grupos 20 y 21 (Viernes 8-10 y 10-12 -> 04-205)</h3>
#
# <h1> <strong>Docente: John Ballesteros </strong></h1>
# <h2><a href="mailto:jballes@unal.edu.co">✉ John Ballesteros</a></h2>
# <h3>Profesor Titular - Departamento de Ciencias de la Computación y de la Decisión</h3>
# <h3>Practicas Grupo 19 (Viernes 6-8 -> 04-205)</h3>

# %% [markdown]
# # QR GitHub del curso
#
#
#
# ![](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/QR_Fundamentos20262.png)
#
# URL -> https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/QR_Fundamentos20262.png

# %% [markdown]
# # Ajustes a la evaluación del curso

# %% [markdown]
# # Evaluación del curso
#
# | Componente | Porcentaje | Descripción |
# |---|---|---|
# | **Pruebas Evaluativas** | **60%** | |
# | Prueba 1 | 20% | Escrita (aula de práctica) |
# | Prueba 2 | 20% | Digital (plataforma MinasLAP) |
# | Prueba 3 | 20% | Escrita (aula de práctica) |
# | **Talleres Prácticos** | **40%** | |
# | Taller práctico 1 | 13% | MinasLAP |
# | Taller práctico 2 | 13% | MinasLAP |
# | Taller práctico 3 | 14% | MinasLAP |
# | **Total** | **100%** | |

# %% [markdown]
# ## Semana 2 — CONDICIONALES
# **(Lunes 7 de septiembre a 13 de septiembre)**
#
# 1. Operadores relacionales: <, >, <=, >=, ==, !=
# 2. Operadores lógicos: And, Or, Not
# 3. Condicional simple, condicional compuesto
# 4. Anidación y condicional múltiple
# 5. Switch
# 6. Comentarios y depuración

# %% [markdown]
# ### 1\. Operadores relacionales
#
# Los operadores de comparación o más conocidos como operadores relacionales se utilizan para comparar valores de las variables y tiene como respuesta una variable booleana de Falso o Verdadero, se debe interpretar siempre como una respuesta de este tipo.
#
# Operador | Nombre | Ejemplo
# --- | ---  | ---
# `==` | Igual | `x == y`
# `!=` | No Igual | `x != y`
# `>` | Mayor que | `x > y`
# `<` | Menor que | `x < y`
# `>=` | Mayor o igual que | `x >= y`
# `<=` | Menor o igual que | `x <= y`

# %%
# Igualdad
x = 1
y = 2
print(x == y)

# %%
# Diferente
print(x != y)

# %%
# Mayor que y menor que
print(x > y)
print(x < y)

# %%
# Mayor o igual que y menor o igual que
print(x >= y)
print(x <= y)

# %% [markdown]
# ### 2\. Operadores Lógicos
#
# Los operadores lógicos son operadores que permiten formular condiciones complejas a partir de condicionales simples. Los operadores lógicos son de conjunción (`and`), disyunción (`or`) y negación (`not`), estos se utilizan para combinar declaraciones condicionales o relacionales:
#
# Operador | Descripción | Ejemplo
# --- | ---  | ---
# `and` | Retorna True si ambos son True | `x > 5 and  x < 10`
# `or` | Retorna True si alguno es True | `x > 5 or x < 10`
# `not` | Revierte el resultado, si es True retorna False y viceversa | `not(x > 5 and  x < 10)`
#
# ---
#
# **Tabla de verdad de los Operadores Lógicos de Python**
#
# Los operadores lógicos se utilizan para combinar declaraciones condicionales o relacionales expresadas como proposiciones:
#
# **P** | **Q** | **not P** | **not Q** | **P or Q** | **P and Q**
# --- | ---  | ---   | ---  | ---  | ---
# **True** | **True** | False | False | True | True
# **True** | **False** | False | True | True | False
# **False** | **True** | True | False | True | False
# **False** | **False** | True | True | False | False
#
# ---
#
# A continuación demostremos los operadores lógicos con figuras geometricas.
#
# Sigue lo siguientes pasos.
# 1. Accede a la aplicacion en el siguiente enlace:
# >* https://app.diagrams.net/
# 2. Clic en `Archivo-->Abrir desde-->URL`
# 3. Ingresa la siguiente URL en la ventana de dialogo.
# >* https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/assets/OperadoresLogicos.drawio
# 4. Sigue los pasos del docente.

# %% [markdown]
# **Recordemos la jeraquía de los operadores de Python, ahora con los operadores relacionales y lógicos en mente.**
#
# Los operadores tienen una jerarquía de operación cuando están involucrados en operaciones conjuntas, la siguiente tabla muestra la jerarquía de ejecución.
#
# Prioridad | Operador | Descripción
# --- | ---  | ---
# 1 | `(expressions...),[expressions...], {key: value...}, {expressions...}` | Parentesis, listas, diccionarios o conjuntos
# 2 | `x[index], x[index:index], x(arguments...), x.attribute` | Suscripcion, slicing, llamadas, atributos de referencia
# 4 | `**` | Potenciación
# 5 | `*, @, /, //, %` | Multiplicación, multiplicación matricial, división, división entera, módulo
# 6 | `+, -` | Suma y resta
# 7 | `in, not in, is, is not, <, <=, >, >=, !=, ==` | Comparisons, including membership tests and identity tests
# 8 | `not x` | Expresion Booleana Negación
# 9 | `and` | Expresion Booleana Y
# 10 | `or` | Expresion Booleana O
# 11 | `if – else` | Expresion condicional
# 12 | `:=` | Expresion de asignacion

# %% [markdown]
# ### 3\. Condicional simple, condicional compuesto

# %% [markdown]
# #### 3.1 Definición de condicionales
#
# Las estructuras algorítmicas selectivas o condicionales concentran gran parte de los problemas computaciones y las vemos continuamente en nuestro día a día cuando debemos tomar una decisión y así saber que camino o acción realizamos.
#
# Las decisiones en la vida real se relacionan con una pregunta, por ejemplo, si tenemos varias opciones para ir a nuestro hogar podemos preguntarnos. ¿Qué opción debo tomar para llegar a mi hogar, bus, tren, Uber, otro?
#
# La respuesta va ligada a una decisión tomada por el actor dependiendo aspectos económicos, de tiempo u otros para definir el medio de transporte elegido.
#
# En dicho caso se puede optar por una sola condición, por ejemplo, si me interesa solo el tiempo de tránsito, consideraría tomar un Uber. Si tengo multiples restricciones como por ejemplo económicas elegiría el tren o el bus para minimizar el costo de tránsito. Estas situaciones se conocen como decisiones en cascada, es decir, una decisión afecta la siguiente y así sucesivamente hasta llegar a un resultado (tomar una decisión).
#
# ---
#
# Las estructuras algorítmicas selectivas se utilizan para la toma de decisiones lógicas las podemos clasificar de la siguiente forma.
#
#
# *   Si Entonces
# *   Si Entonces / Sino
# *   Estructuras selectivas en cascada (Anidadas)
# *   Switch - Casos

# %% [markdown]
# #### 3.2 Regla de fuera de juego (Off-side rule) en Python
#
# ¿Qué es?
#
# La regla de fuera de juego (*off-side rule*, tomada prestada del término futbolístico) es la norma que dice que Python usa la indentación (los espacios o tabulaciones al inicio de una línea) para definir bloques de código, en lugar de usar llaves `{}` como otros lenguajes (C++, Java, JavaScript).
#
# > En Python, la indentación no es solo estética: es parte de la sintaxis. Si la indentación está mal, el programa no funciona.
#
# ---
#
# **¿Cómo funciona?**
#
# Todo el código que pertenece a un mismo bloque (dentro de un `if`, un `for`, una función, etc.) debe estar alineado con el mismo nivel de sangría, generalmente 4 espacios.
#
# ```python
# # Correcto ✅
# if edad >= 18:
#     print("Eres mayor de edad")   # pertenece al bloque del "if"
#     print("Puedes votar")          # también pertenece al bloque
#
# print("Este mensaje siempre se muestra")  # está "fuera" del if
# ```
#
# ```python
# # Incorrecto ❌ (error de indentación)
# if edad >= 18:
# print("Eres mayor de edad")   # Python arroja error: se esperaba indentación
# ```
#
# ---
#
# **¿Por qué es importante?**
#
# - Obliga a escribir código ordenado y legible desde el principio.
# - Evita errores comunes, ya que no puedes "olvidar" cerrar un bloque como con las llaves.
# - Es la causa más frecuente de errores (`IndentationError`) en estudiantes que recién empiezan.
#
# ---
#
# > 💡 Idea clave: en Python, la sangría no es una cuestión de estilo, es obligatoria. Un espacio de más o de menos puede cambiar por completo el comportamiento del programa. Se recomienda que sean cuatro espacios.
#
# ---

# %% [markdown]
# #### 3.3 Condicional Simple
#
# La estructura selectiva *si entonces* o condicional simple, permite que el flujo del algoritmo siga por un camino especifico si se cumple una condición o conjunto de condiciones. Si al evaluar la condición (o condiciones) el resultado es verdadero, entonces se ejecutan ciertas operaciones. Luego se continúa con la secuencia normal del programa.
#
# Esta acción es aplicable por ejemplo a cuando mis compras tienen un descuento si estoy cumpliendo años me dan el 10% de descuento de lo contrario no se hace ninguna operación, solo aplico el descuento si se cumple la condición de ser mi día de cumpleaños. 🥳
#
# ---
#
# ![Simple](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/condicional_simple.PNG)
#
# ---
#
# **Usando `if`**
#
# La condición `if` se considera la más simple de las tres y toma una decisión en función de si la condición es verdadera o no. Si la condición es verdadera, imprime la expresión con sangría. Si la condición es falsa, omite la impresión de la expresión con sangría.
# Es muy importante detallar que al terminar la condición debemos escribir dos puntos `:` indicando la finalización de la condición.
# La sangría o el sangrado indica que las expresiones detalladas se realizan en el entorno de la condición verdadera.
#
#
# ```python
# if (condición):
#     expresión
# ```

# %%
#Ejemplo de if, se da un descuento de 5% a los niños en la compra de los helados
edad = int(input('Ingresar la edad->'))
costo_helado = 5000
if edad < 18:
    total = costo_helado * 0.95
    print('Descuento aplicado por ser menor de edad')
print('Total a pagar $',total)

# %% [markdown]
# ##### `Ejemplo 1`
#
# Ingresar la calificación de un estudiante, si la nota es mayor o igual a 3 imprimir aprobado.
#
# Nivel de dificultad:★★☆☆☆

# %%
#Ejecutar la solución aquí
nota = int(input('Ingresar el valor de la nota del estudiante: '))
if nota >= 3:
    print('Aprobado')

# %% [markdown]
# ##### `Ejemplo 2`
#
# Ingresar el sueldo de un trabajador, si este es inferior al salario mínimo para el año 2024, aplicarle un incremento del 10% e imprimir el nuevo salario. (Consultar el [salario Mínimo](https://www.google.com/search?q=salario+minimo+2024).)
#
# Nivel de dificultad:★★☆☆☆

# %%
#Ejecutar la solución aquí
SALARIO_MINIMO = 1300000
salario_empleado = int(input('Ingresar salario: '))
if salario_empleado < SALARIO_MINIMO:
    salario_empleado *= 1.1
print('El nuevo salario del empleado es: ', salario_empleado)

# %% [markdown]
# #### 3.4 Condicional Doble o compuesto
#
# La estructura selectiva si entonces/sino o condicional doble o compuesto, permite que el flujo del algoritmo se bifurque por dos ramas diferentes en el punto de la toma de decisión o decisiones. Si al evaluar la condición o condiciones el resultado es verdadero `True`, entonces se sigue por un camino especifico y se ejecutan ciertas operaciones. Por otra parte, si el resultado es falso `False` se sigue por otro camino y se ejecutan otras operaciones. En ambos casos luego de ejecutarse las operaciones indicadas, se continua con la secuencia normal del algoritmo.
#
# Esta acción es aplicable por ejemplo cuando se necesita clasificar el estado del resultado de una asignatura para un estudiante, en este caso si la condición establece que, si la nota es mayor o igual a tres, en la operación si, se debe registrar que el estudiante ganó la asignatura y en la operación no, se debe registrar que el estudiante pierde la asignatura.
#
#
# ---
#
# ![Si entonces sino](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/condicional_doble.PNG)
#
# ---
# **Usando `if-else`**
#
# La condición `if-else` agrega un paso adicional en el proceso de toma de decisiones en comparación con la declaración `if` simple. El comienzo de una instrucción `if-else` funciona de manera similar a una instrucción `if` simple; sin embargo, si la condición es falsa, en lugar de no imprimir nada, se imprimirá la expresión con sangría debajo de else. Es muy importante detallar que al terminar la condición debemos escribir dos puntos `:` indicando la finalización de la condición, tanto para el `if` como para el `else`.
# La sangría o el sangrado indica que las expresiones detalladas se realizan en el entorno de la condición verdadera y falsa de acuerdo con el flujo del algoritmo.
#
# ```python
# if (condición):
#     expresión True
# else:
#     expresión False
# ```

# %% [markdown]
# ##### `Ejemplo 3`
#
# Ingresar la calificación de un estudiante, si la nota es mayor o igual a 3 imprimir aprobado, de lo contrario imprimir reprobado.
#
#
# Nivel de dificultad:★★☆☆☆

# %%
#Ejecutar la solución aquí
nota = int(input('Ingresar el valor de la nota del estudiante: '))
if nota >= 3:
    print('Aprobado')
else:
    print('Reprobado')

# %% [markdown]
# ##### `Ejemplo 4`
#
# Ingresar el sueldo de un trabajador, si este es inferior al salario mínimo para el año 2024, aplicarle un incremento del 10% e imprimir el nuevo salario, de lo contrario aplicarle un incremento del 5%. (Consultar el [salario Mínimo](https://www.google.com/search?q=salario+minimo+2024).)
#
# Nivel de dificultad:★★☆☆☆

# %%
#Ejecutar la solución aquí
SALARIO_MINIMO = 1300000
salario_empleado = int(input('Ingresar salario: '))
if salario_empleado < SALARIO_MINIMO:
    salario_empleado *= 1.1
else:
    salario_empleado *= 1.05
print('El nuevo salario del empleado es: ', salario_empleado)

# %% [markdown]
# #### 3.5 Anidación y condicional múltiple
#
# Encontramos numerosos casos en el desarrollo de la solución de problemas en el que luego de tomar una decisión y marcar el camino correspondiente a seguir, es necesario tomar otra decisión. Se señala, luego de evaluar las condiciones, la rama correspondiente a seguir, y nuevamente podemos tener que tomar otra decisión. El proceso puede repetirse numerosas veces. En este caso, para resolver el problema, estamos aplicando estructuras selectivas en cascada o anidadas.
#
# ---
# ![Cascada](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/anidacion_condicional_multiple.PNG)
#
# ---
#
# ⚠️ Este es un ejemplo didáctico simplificado para practicar anidación y condicionales múltiples, no reemplaza la verificación oficial de requisitos, que hace directamente la Universidad para la matrícula cero.
#
# Requisitos simplificados que usaremos
# 1. Ser de nacionalidad colombiana o extranjera con permiso de estudio
# 2. Estar admitido en un programa de pregrado
# 3. Pertenecer a estrato 1, 2 o 3 (o sin estrato), o estar en grupo A, B o C del Sisbén IV
# 4. No tener título profesional universitario previo
#
# ---
#
# 💡 Idea clave: la anidación se usa cuando una condición solo tiene sentido evaluarla si otra condición externa ya se cumplió (por ejemplo, no tiene sentido revisar el estrato si la persona ya tiene título previo). El condicional múltiple (elif) se usa cuando hay varias alternativas posibles, no solo dos, como ocurre con los distintos criterios de elegibilidad (estrato o Sisbén o ninguno).
#
# ---

# %% [markdown]
# **Usando `if-elif-else`**
#
# La más compleja de estas condiciones es la condición `if-elif-else`. Cuando se encuentra en una situación en la que tiene varias condiciones, puede colocar tantas condiciones `elif` como sea necesario entre la condición `if` y la condición `else`. Es muy importante detallar que al terminar la condición debemos escribir dos puntos `:` indicando la finalización de la condición, tanto para el `if` como para `elif` y `else`.
# La sangría o el sangrado indica que las expresiones detalladas se realizan en el entorno de la condición verdadera y falsa de acuerdo con el flujo del algoritmo.
#
# ```python
# if (condición 1):
#     expresión True de condición 1
# elif (condición 2)
#     expresión True de condición 2
# else:
#     expresión False
# ```

# %% [markdown]
# ##### `Ejemplo 5`
#
# Ingresados por teclado los valores enteros a, b y c que representan números enteros diferentes, construya un algoritmo para escribir estos en forma descendente.
#
# Nivel de dificultad:★★★★☆

# %%
#Ejecutar la solución aquí
a = int(input('Ingresar a: '))
b = int(input('Ingresar b: '))
c = int(input('Ingresar c: '))
if a > b:
    if a > c:
        if b > c:
            print(a,b,c)
        else:
            print(a,c,b)
    else:
        print(c,a,b)
else:
    if b > c:
        if a > c:
            print(b,a,c)
        else:
            print(b,c,a)
    else:
        print(c,b,a)
print('Fin')

# %% [markdown]
# ##### `Ejemplo 6`
#
# Ingresar por teclado un numero entero y determinar si es positivo, negativo o cero.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Ejecutar la solución aquí
num = int(input('Ingresar un número entero: '))
if num > 0:
    print('Positivo')
elif num == 0:
    print('Cero')
else:
    print('Negativo')
print('Fin')

# %% [markdown]
# #### 3.6 Switch
#
# La estructura selectiva Switch, conocido como *si múltiple*, permite que el flujo del diagrama se bifurque por varias ramas en el punto de la toma de decisiones, esto en función del valor que tome el selector.
#
# *   Selector: es la variable o expresión a evaluarse, según la cual se tomará una de las múltiples decisiones o alternativas.
# >*   Acción 1: Expresa la operación o conjunto de operaciones que se van a realizar si el selector toma el valor de 1.
# >*   Acción 2: Expresa la operación o conjunto de operaciones que se van a realizar si el selector toma el valor de 2.
# >*   Acción n: Expresa la operación o conjunto de operaciones que se van a realizar si el selector toma el valor de n.
# >*   Acción n+1: Expresa la operación o conjunto de operaciones que se van a realizar cuando se continúe con el flujo normal del programa.
#
# Esta acción es aplicable por ejemplo a los botones de ejecución de un cajero electrónico, o por ejemplo a la selección de la fila donde registraré los productos del supermercado, allí aplicamos la condición de escoger la que tiene menor cantidad de productos, pero siempre tengo múltiples opciones de las cuales debo escoger una y al final debo pagar.
#
# ---
#
# ![Cascada](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/switch.PNG)
#
# ---

# %% [markdown]
# **Usando `match-case`**
#
# La instrucción match en Python es una característica introducida en Python 3.10 como parte de la Propuesta de Mejora de Python (PEP) 634. Es una forma de hacer coincidir patrones en Python, similar a cómo se usan las declaraciones switch o case en otros lenguajes de programación. Esta característica permite una forma más limpia y legible de hacer coincidir objetos con ciertas condiciones.
#
# La instrucción match trabaja principalmente con literales, tipos de datos, y estructuras como listas o diccionarios, permitiendo realizar diferentes acciones dependiendo del patrón que coincida con el valor dado.
#
# ```python
# match dato:
#     case opcion_1:
#         print("Opción 1")
#     case opcion_2:
#         print("Opción 2")
#     case opcion_3:
#         print("Opción 3")
#     case _:
#         print("Opción no reconocida")
# ```

# %% [markdown]
# ##### `Ejemplo 7`
#
# Ingresar dos números enteros y un simbolo aritmetico de los detallados en el notebook 2 `['+', '-', '*', '/', '**', '%', '//']` para sobre los dos números ingresados en dicho orden. Utilizar `match-case` para elegir y validar el simbolo y luego aplicar la operación detallada.
#
# Nivel de dificultad:★★☆☆☆

# %%
numero1 = None # @param {type:"integer"}
numero2 = None # @param {type:"integer"}
operador = "+" # @param ["+", "-", "*", "/", "**", "%", "//"]

match operador:
    case "+":
        print("Suma")
        resultado = numero1 + numero2
    case "-":
        print("Resta")
        resultado = numero1 - numero2
    case "*":
        print("Multiplicación")
        resultado = numero1 * numero2
    case "/":
        print("División")
        resultado = numero1 / numero2
    case "**":
        print("Potenciación")
        resultado = numero1 ** numero2
    case "%":
        print("Módulo")
        resultado = numero1 % numero2
    case "//":
        print("División Entera")
        resultado = numero1 // numero2
    case _:
        print("Opción no reconocida")
print('Resultado =', resultado)

# %% [markdown]
# ##### `Ejemplo 8`
#
# Ingresar el sueldo de un trabajador y una categoria entre `A`, `B` y `C`. Aplicar un incremento al salario de acuerdo a las siguientes condiciones:
# *   Si la categoria es `A` aplicar un incremento del 25%.
# *   Si la categoria es `B` aplicar un incremento del 15%.
# *   Si la categoria es `C` aplicar un incremento del 10%.
#
# Nivel de dificultad:★★☆☆☆

# %%
sueldo = 7000000 # @param {type:"integer"}
categoria = "A" # @param ["A", "B", "C"]
match categoria:
    case "A":
        salario = sueldo*1.25
    case "B":
        salario = sueldo*1.15
    case "C":
        salario = sueldo*1.1
print('El salario incrementado para la categoria', categoria)
print('\t$', salario)

# %% [markdown]
# ### 4\. Ejercicios de practica

# %% [markdown]
# #### 4.1 Ejercicios de practica con bonificación de nota
#
# [MinasLAP Enlace](https://minaslap.net/course/view.php?id=137)
#
# ![](https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion2026/refs/heads/main/img/MinasLAP_Condicionales.png)

# %% [markdown]
# #### 4.2 Ejercicios de practica

# %% [markdown]
# ##### `Ejercicio 01`
#
# Ingresar por teclado un numero entero y determinar si es par, impar o cero. Usar potenciación para solucionar el presente ejercicio.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 02`
#
# Ingresar por teclado un numero entero y determinar si es par, impar o cero. Usar módulo para solucionar el presente ejercicio.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 03`
#
# Construya un algoritmo que de acuerdo a tres números enteros ingresados, determinar si estos fueron ingresados en orden creciente.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 04`
#
# En una tienda efectúan un descuento a los clientes dependiendo del monto de la compra. El descuento se efectúa con base en la siguiente tabla:
#
# Valor | Descuento  | Límites
# ---|---|---
# Entre 1 y 50.000 | <center>0%</center> | 50.000 Inclusive
# Entre 50.000 y 100.000 | <center>5%</center> | 100.000 Inclusive
# Entre 100.000 y 700.000 | <center>11% </center>| 700.000 Inclusive
# Entre 700.000 y 1.500.000 | <center>18%</center> | 1.500.000 Inclusive
# Mayor a 1.500.000 | <center>25%</center> | Solo Mayor a 1.500.000
#
# Construya un algoritmo que imprima el valor a pagar incluyendo el descuento.
# Nota: Usar operadores lógicos
#
# Nivel de dificultad:★★★☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 05`
#
# Determinar el mayor de dos números ingresados por teclado.
#
# Nivel de dificultad:★★☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 06`
#
# Que lea un número entero y muestre un mensaje informando si es múltiplo de 3.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 07`
#
# Que lea un número entero y muestre un mensaje informando si es múltiplo de 7.
#
# Nivel de dificultad:★☆☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 08`
#
# Que, dadas dos edades, retorne la edad promedio si una de las edades es superior al doble de la otra, de lo contario retorne la diferencia de edades.
#
# Nivel de dificultad:★★☆☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 09`
#
# La ecuación de segundo grado:
#
# $ax² + bx + c = 0$
#
# puede tener una, dos o ninguna solución. Depende del valor del Discriminante:
#
# $D = b^2 - 4ac$
#
# $D=0$
#
# Dos soluciones reales iguales. (Una solución.)
# Realice un algoritmo en el cual precise si una ecuación de segundo grado se puede solucionar en los reales.
#
# Nivel de dificultad:★★★☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 10`
#
#
# En una determinada empresa se estimula a los trabajadores ayudándoles con una cuota dedicada para pago de matrículas de colegio y universidad de sus hijos de acuerdo con la siguiente tabla:
#
# Porcentajes por estrato
#
# 1 | 2 | 3 | 4 | 5 | 6
# ---|---|---|---|---|---
# 70% | 60% | 50% | 30% | 15% | 5%
#
# Elabore un algoritmo que calcule la ayuda económica brindada al trabajador de acuerdo al salario ingresado por teclado.
#
#
# Nivel de dificultad:★★★☆☆

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 11`
#
# Link necesita comprar flechas en el mercado Kokiri, cada flecha tiene un costo de 5 rupias, si compra más de 15 flechas valen 4 rupias, si compra más de 45 quedan a 3 rupias, pero si además de esto compra una poción roja, las flechas tienen un 20% de descuento sobre el monto total de la compra, si además compra una poción verde tendrá un descuento del 30%, pero si solo compra la poción verde tendrá un descuento del 10%.
#
# Calcular el valor total de venta para la cantidad de flechas compradas y si compra o no pociones.
#
#
# Nivel de dificultad:★★★☆☆
#
# ![Link](https://storage.googleapis.com/multi-static-content/thumbs/artage-io-thumb-1666557522561c2881979d96e74b0673.png)

# %%
flechas = 50 #@param {type:"slider", min:1, max:100, step:1}
pociones = "Ambas" #@param ["Pocion Roja", "Pocion Verde", "Ambas", "Ninguna"]

# %%
#Solución

# %% [markdown]
# ##### `Ejercicio 12`
#
# El impuesto predial en el Municipio de Medellín se calcula de acuerdo con el estrato socioeconómico y al avalúo catastral del inmueble. Realice un algoritmo que calcule el impuesto predial, basándose en el avalúo y el estrato, utilizando la siguiente tabla:
#
# Avalúo | Estrato 1 | Estrato 2 | Estrato 3 | Estrato 4 | Estrato 5 | Estrato 6
# ---|---|---|---|---|---|---
# De 0 a 5.000.000 | 6 Por Mil | 7 Por Mil | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil
# De 5.000.001 a 50.000.000 | 7 Por Mil | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil
# De 50.000.001 a 100000000 | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil
# De 100.000.001 a 300000000 | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil | 14 Por Mil
# De 300.000.001 en adelante | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil | 14 Por Mil | 15 Por Mil
#
#
# Nivel de dificultad:★★★★☆

# %%
estrato = 1 #@param {type:"slider", min:1, max:6, step:1}
avaluo =  0#@param {type:"integer"}

# %%
#Solución

# %% [markdown]
# ### **Ejercicios Propuestos**
#
# 1.	Construir un algoritmo que reciba tres números enteros y determinar cuál o cuales son los mas lejanos al promedio de estos. ★★★★★
#
# 2.	Construir un algoritmo que reciba tres números y determine cuales son pares e impares. Si todos son impares mostrar el mensaje “That’s odd”. ★★☆☆☆
#
# 3.	Construir un algoritmo que reciba cuatro números y determinar si su suma es positiva, negativa o es cero. ★★☆☆☆
#
# 4.	Construir un algoritmo que reciba tres valores y determinar si estos pueden construir un triángulo (La suma de dos lados debe ser siempre mayor que el lado restante). ★★☆☆☆
#
# 5.	Construir un algoritmo que lea la fecha de nacimiento de un usuario usando formularios y determinar si es mayor de edad y si nació en un año bisiesto o no. ★★★☆☆
#
# 6.	Construir un algoritmo que reciba las cinco notas de un curso y sus respectivos porcentajes, validar que los porcentajes sumen cien, que las notas se encuentren entre 0 y 5 inclusive y luego determinar si el curso se ha ganado, perdido, pero habilitable o perdido sin habilitación. ★★★☆☆
#
# 7.	Construir un algoritmo que reciba el día de la semana (lunes, martes, …, etc.) y determinar si es día hábil o fin de semana. ★☆☆☆☆
#
# 8.	Construir un algoritmo que reciba los datos necesarios para calcular el índice de masa corporal (ver ejercicios secuenciales, ya resuelto) y determinar si corresponde a peso bajo, peso normal, sobrepeso, obesidad leve, obesidad media u obesidad mórbida. Se pueden tomar los datos de la siguiente fuente [URL](https://www.topdoctors.mx/diccionario-medico/indice-de-masa-corporal-imc/ )  ★★★☆☆
#
# 9.	Construya un algoritmo que calcule el incremento de salario de una persona dependiendo de la categoría a la cual pertenezca, utilice la tabla a continuación para determinar el valor a incrementar (Utilizar match-case.). ★★★☆☆
# <div align="center">
#
# | Categoría | Incremento |
# |---|---|
# | A | 10% |
# | B | 15% |
# | C | 20% |
# | D | 25% |
#
# </div>
#
# 10. Construir un algoritmo que permita solucionar el siguiente problema: Un país calcula los impuestos a compras de la siguiente manera: los primeros \$100.000 no causan impuesto, los siguientes \$100.000 tienen el 25% de impuesto, el resto tienen el 40% de impuesto. Pero si el producto supera los \$500.000 el ultimo rango se cobra el 50% de impuesto. Calcule el valor a pagar por impuesto, valor total y en caso de no tener que pagar impuesto, informarlo. ★★★★☆
#
# 11.	Construir un algoritmo que dados tres números reales identifique cual o cuales (solo dos) son el mayor. Considere que los números puedes ser iguales y notificar el estado final. ★★★★★
